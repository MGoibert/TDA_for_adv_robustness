# %%
from tda.rootpath import db_path
from r3d3.experiment_db import ExperimentDB
import qgrid
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (8,6)

# %%
db_path = '/Users/m.goibert/Downloads/r3d3.db'
my_db = ExperimentDB(db_path)

# %%
qgrid.show_grid(my_db.list_all_experiments())
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
# Experiment id and kind of experiment correspondance
mnist_mlp_fgsm = 1579614448
mnist_mlp_bim = 1579631922
mnist_mlp_deepfool = 1579649318
mnist_mlp_cw = 1579649318

svhn_lenet_fgsm = 1579614665
svhn_lenet_bim = 1579681001
svhn_lenet_deepfool = 1579765053
svhn_lenet_cw = 1579818796

mnist_lenet_fgsm = 1579674580
mnist_lenet_bim = 1579704898
mnist_lenet_deepfool = 1579765019
mnist_lenet_cw = 1579778212

# %%
# These are the results of experiments run on 100 examples.
df_mnist_mlp_fgsm = my_db.show_experiment(mnist_mlp_fgsm,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_mnist_mlp_bim = my_db.show_experiment(mnist_mlp_bim,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_mnist_mlp_deepfool = my_db.show_experiment(mnist_mlp_deepfool,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_mnist_mlp_cw = my_db.show_experiment(mnist_mlp_cw,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_svhn_lenet_fgsm = my_db.show_experiment(svhn_lenet_fgsm,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_svhn_lenet_bim = my_db.show_experiment(svhn_lenet_bim,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_svhn_lenet_deepfool = my_db.show_experiment(svhn_lenet_deepfool,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_svhn_lenet_cw = my_db.show_experiment(svhn_lenet_cw,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_mnist_lenet_fgsm = my_db.show_experiment(mnist_lenet_fgsm,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_mnist_lenet_bim = my_db.show_experiment(mnist_lenet_bim,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_mnist_lenet_deepfool = my_db.show_experiment(mnist_lenet_deepfool,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })
df_mnist_lenet_cw = my_db.show_experiment(mnist_lenet_cw,
    params={
        "attack": "attack_type"
    },
    metrics={
        "val": "separability_values",
        "l2_diff": "l2_diff",
        "linf_diff": "linf_diff"
    })

# %%
epsilon = list(df_mnist_mlp_fgsm['val'][0].keys())
epsilon = [float(item) for item in epsilon]
epsilon = [epsilon[4]] + epsilon[0:4]
epsilons = {
    "FGSM": epsilon,
    "BIM": epsilon,
    "DeepFool": [0,0.40],
    "CW": [0, 0.40]
}
epsilons
# Out:
# {'FGSM': [0.0, 0.025, 0.05, 0.1, 0.4],
#  'BIM': [0.0, 0.025, 0.05, 0.1, 0.4],
#  'DeepFool': [0, 0.4],
#  'CW': [0, 0.4]}

# %%
mnist_mlp_auc = {
    "FGSM": [list(df_mnist_mlp_fgsm['val'][0].values())[4]]+list(df_mnist_mlp_fgsm['val'][0].values())[0:4],
    "BIM": [list(df_mnist_mlp_bim['val'][0].values())[4]]+list(df_mnist_mlp_bim['val'][0].values())[0:4],
    "DeepFool": [list(df_mnist_mlp_deepfool['val'][0].values())[1]]+[list(df_mnist_mlp_deepfool['val'][0].values())[0]],
    "CW": [list(df_mnist_mlp_cw['val'][0].values())[1]]+[list(df_mnist_mlp_cw['val'][0].values())[0]]
}
mnist_lenet_auc = {
    "FGSM": [list(df_mnist_lenet_fgsm['val'][0].values())[4]]+list(df_mnist_lenet_fgsm['val'][0].values())[0:4],
    "BIM": [list(df_mnist_lenet_bim['val'][0].values())[4]]+list(df_mnist_lenet_bim['val'][0].values())[0:4],
    "DeepFool": [list(df_mnist_lenet_deepfool['val'][0].values())[1]]+[list(df_mnist_lenet_deepfool['val'][0].values())[0]],
    "CW": [list(df_mnist_lenet_cw['val'][0].values())[1]]+[list(df_mnist_lenet_cw['val'][0].values())[0]]
}
svhn_lenet_auc = {
    "FGSM": [list(df_svhn_lenet_fgsm['val'][0].values())[4]]+list(df_svhn_lenet_fgsm['val'][0].values())[0:4],
    "BIM": [list(df_svhn_lenet_bim['val'][0].values())[4]]+list(df_svhn_lenet_bim['val'][0].values())[0:4],
    "DeepFool": [list(df_svhn_lenet_deepfool['val'][0].values())[1]]+[list(df_svhn_lenet_deepfool['val'][0].values())[0]],
    "CW": [list(df_mnist_lenet_cw['val'][0].values())[1]]+[list(df_mnist_lenet_cw['val'][0].values())[0]]
}
svhn_lenet_auc
# Out:
# {'FGSM': [0.5, 0.9806, 0.9928, 0.9964, 0.9442],
#  'BIM': [0.5, 0.9662, 0.9951, 0.9950999999999999, 0.9868000000000001],
#  'DeepFool': [0.5, 0.9553],
#  'CW': [0.49999999999999994, 1.0]}

# %%
for i in range(4):
    plt.style.use('ggplot')
    plt.plot(epsilons[list(mnist_mlp_auc.keys())[i]],
             mnist_mlp_auc[list(mnist_mlp_auc.keys())[i]], "o:",
             label=list(mnist_mlp_auc.keys())[i], alpha=0.7)
    #plt.plot([0,0.41],[1,1], "--")
    plt.title(f"Non-supervised results for MNIST MLP")
    plt.xlabel(f"L-inf perturbation (epsilon)")
    plt.ylabel(f"AUC")
plt.legend(title="Attack type")
plt.show()

# %%
for i in range(4):
    plt.style.use('ggplot')
    plt.plot(epsilons[list(svhn_lenet_auc.keys())[i]],
             svhn_lenet_auc[list(svhn_lenet_auc.keys())[i]], "o:",
             label=list(svhn_lenet_auc.keys())[i], alpha=0.7)
    #plt.plot([0,0.41],[1,1], "--")
    plt.title(f"Non-supervised results for SVHN LeNet")
    plt.xlabel(f"L-inf perturbation (epsilon)")
    plt.ylabel(f"AUC")
plt.legend(title = "Attack type")
plt.show()

# %%
for i in range(4):
    plt.style.use('ggplot')
    plt.plot(epsilons[list(mnist_lenet_auc.keys())[i]],
             mnist_lenet_auc[list(mnist_lenet_auc.keys())[i]], "o:",
             label=list(mnist_lenet_auc.keys())[i], alpha=0.7)
    #plt.plot([0,0.41],[1,1], "--")
    plt.title(f"Non-supervised results for MNIST LeNet")
    plt.xlabel(f"L-inf perturbation (epsilon)")
    plt.ylabel(f"AUC")
plt.legend(title = "Attack type")
plt.show()
